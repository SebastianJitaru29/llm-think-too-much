# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

gauth = GoogleAuth()
gauth.LocalWebserverAuth()  # opens browser
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=831354245508-tua01hqr50gmg9jjcq7jja316oq1cic0.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.

# %%
folder_id = '1O3DsRty6eLwhh-0e3TZcd2uZud6jSBmH'

# %%
def get_files(folder_id):
    return drive.ListFile(
        {'q': f"'{folder_id}' in parents"}
    ).GetList()

# %%
def upload_file(file_path, folder_id):
    f = drive.CreateFile({
        'title': file_path.split('/')[-1],
        'parents': [{'id': folder_id}]
    })
    f.SetContentFile(file_path)
    f.Upload()
    return f['id']

# %%
files = get_files(folder_id)
for file in files:
    print(f'Title: {file["title"]}, ID: {file["id"]}')
    
def download_file(file_id, destination_path):
    f = drive.CreateFile({'id': file_id})
    f.GetContentFile(destination_path)

for file in files:
    download_file(file['id'], file['title'])
# Out:
# Title: eval_data_final.zip, ID: 12d27MpJQ6t3wM_G-xNDbVvk5gLxmYDJx
# Title: eval_dataset.zip, ID: 14n9Bt5_QohrPbjJZrLwEZxv1bofiodXd
# Title: train.parquet, ID: 1mnjuUNQlO1gRONo7BEv1DBxYuSIPmvZM
# Title: test.parquet, ID: 1uM5pfAcwpP63ITrS6HxLOomezo7jNMny

# %%
upload_file('../../processed/eval/eval_data_final.zip', folder_id)
# Out:
# '12d27MpJQ6t3wM_G-xNDbVvk5gLxmYDJx'
